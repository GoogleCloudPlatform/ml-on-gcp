# %% [markdown]
# # ML APIs as preprocessors for scikit-learn
# Unstructured data (like documents, audio, images or video) can be difficult to preprocess into a usable state for traditional ML frameworks like scikit-learn and xgboost.
#
# This notebook gives an example of using Google's Building Blocks APIs to extract structure from unstructured data.

# %% [markdown]
# ## Use case: Tokenization with the Natural Language API
#
# As an example use case, consider that most NLP requires that text first be preprocessed with a technique like TfIdf (Term Frequency / Inverse Document Frequency). This first requires that the text be separate into distinct words or "tokens".
#
# This is trivial in English. Words are separated by spaces.
#
# However, Japanese characters are not separated by spaces or other break characters. So tokenizing text requires understanding the language. Google's Natural Language API does this without requiring special language knowledge or a dictionary.
#
# ### Acknowledgements
# This example is adapted, with permission, from [Hayato Yoshikawa](https://github.com/hayatoy). Here is the [original slide deck](https://www.slideshare.net/HayatoYoshikawa/using-cloud-natural-language-api-as-a-preprocessor) and here is the [original notebook](https://github.com/sgreenberg/misc-ml/blob/master/NL_API_for_tokenization_orig.ipynb)
#
# The concept of distinguishing between New York Times and TechCrunch headlines in Hacker News headlines is used, with permission, from [Lak Lakshmanan](https://aisoftwarellc.weebly.com/)'s blog post, [How to do text classification with CNNs, TensorFlow and word embedding](https://towardsdatascience.com/how-to-do-text-classification-using-tensorflow-word-embeddings-and-cnn-edae13b3e575)

# %% [markdown]
# ## Getting Hacker News headlines from BigQuery
#
# Hacker News headlines are available in the `bigquery-public-data.hacker_news.stories` public dataset.
#
# For the purposes of this demo, I extracted and translated a small number of them. (The original query can be found in the appendix below.)

# %%
# Note I have set up GOOGLE_APPLICATION_CREDENTIALS environment variables
# per https://google-cloud-python.readthedocs.io/en/latest/bigquery/usage.html#id3

from google.cloud import bigquery
client = bigquery.Client()

# %%
# Enable magics in BigQuery. See https://google-cloud-python.readthedocs.io/en/latest/bigquery/generated/google.cloud.bigquery.magics.html#module-google.cloud.bigquery.magics
# %load_ext google.cloud.bigquery

# %%
# %%bigquery df
# SELECT * FROM `sgreenberg-project2.misc_ml.hacker_news_stories`
# ORDER BY id
# Out:
#         source                                              title  \
# 0   techcrunch            From Social Networks to Market Networks
# 1   techcrunch                     地下貯蔵庫を持つワイン購入サイトが無料のワインボトルを進呈中
# 2   techcrunch  Underground Cellar A Wine-Buying Site That Rew...
# 3   techcrunch          AndroidユーザーはGoogle Playで公開予定のアプリの事前登録が可能に
# 4   techcrunch  Android Users Can Now Pre-Register for Upcomin...
# 5   techcrunch                                 最新500社のスタートアップ企業一覧
# 6   techcrunch  Here s the Latest Batch of 500 Startups Companies
# 7      nytimes       Google Unveils Plan for New Corporate Campus
# 8      nytimes                             Google、新しい企業キャンパス計画を発表
# 9      nytimes  The Risk of a Billion-Dollar Valuation in Sili...
# 10     nytimes                            シリコンバレーにおける10億ドルの評価のリスク
# 11     nytimes  NYC Mayor to require computer science in city ...
# 12     nytimes  4chan Message Board Sold  to Founder of 2Chann...
# 13     nytimes  Big Price Increase for Tuberculosis Drug Is Re...
# 14  techcrunch  The 6 TechCrunch Disrupt SF 2015 Battlefield F...
# 15     nytimes                 Is College Tuition Really Too High
# 16     nytimes                                      大学の授業料は本当に高い?
#
#                      time_ts        id
# 0  2015-06-28 00:31:48+00:00   9791977
# 1  2015-10-29 00:54:20+00:00   9791978
# 2  2015-10-29 00:54:20+00:00   9791978
# 3  2015-10-01 00:54:20+00:00   9791979
# 4  2015-10-01 00:54:20+00:00   9791979
# 5  2015-11-03 00:54:20+00:00   9791980
# 6  2015-11-03 00:54:20+00:00   9791980
# 7  2015-08-12 00:02:29+00:00  10045195
# 8  2015-08-12 00:02:29+00:00  10045195
# 9  2015-08-29 00:54:20+00:00  10138569
# 10 2015-08-29 00:54:20+00:00  10138569
# 11 2015-09-15 23:29:44+00:00  10223767
# 12 2015-09-21 22:41:41+00:00  10255585
# 13 2015-09-21 22:43:57+00:00  10255601
# 14 2015-09-23 06:36:19+00:00  10263615
# 15 2015-09-29 04:50:13+00:00  10294707
# 16 2015-09-29 04:50:13+00:00  10294707

# %% [markdown]
# ## Attempt to tokenize
#
# Tokenization is poor for Japanese text. Each headline is counted as a distinct word.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
import numpy as np
import pandas as pd
vectorizer = TfidfVectorizer(sublinear_tf=True)

vocab = vectorizer.fit(df.title).vocabulary_
vocab_df = pd.DataFrame(vocab.items())
vocab_df
# Out:
#                                  0   1
# 0                          founder  28
# 1                           dollar  24
# 2                         startups  67
# 3                            mayor  40
# 4                           market  39
# 5                              web  81
# 6                             from  30
# 7          シリコンバレーにおける10億ドルの評価のリスク  85
# 8                             apps   6
# 9               androidユーザーはgoogle   5
# 10                              to  71
# 11                           board  11
# 12                            2015   0
# 13                          valley  79
# 14                         disrupt  23
# 15                      techcrunch  68
# 16                             500   3
# 17                             too  72
# 18                         rewards  58
# 19                            risk  59
# 20                        upcoming  77
# 21                            that  69
# 22                             big   9
# 23                            site  64
# 24                        2channel   1
# 25                    tuberculosis  73
# 26                             nyc  45
# 27                         schools  60
# 28                             now  44
# 29                            with  83
# ..                             ...  ..
# 60                         pioneer  48
# 61                     underground  75
# 62                             new  43
# 63                             you  84
# 64                           price  53
# 65                            play  50
# 66                          cellar  16
# 67                           users  78
# 68                 新しい企業キャンパス計画を発表  88
# 69                            city  17
# 70                       valuation  80
# 71                            sold  66
# 72                            here  32
# 73                         tuition  74
# 74                            free  29
# 75                          latest  38
# 76                         billion  10
# 77                              on  47
# 78              最新500社のスタートアップ企業一覧  89
# 79                              of  46
# 80                       rescinded  57
# 81                        register  55
# 82                            drug  25
# 83                         silicon  63
# 84                          social  65
# 85                             the  70
# 86                            wine  82
# 87                       corporate  21
# 88                              sf  62
# 89  地下貯蔵庫を持つワイン購入サイトが無料のワインボトルを進呈中  86
#
# [90 rows x 2 columns]

# %% [markdown]
# ## Adding a space between words
# This is done using Google's Natural Language API

# %%
# Note I enabled the Natural Language API on this project.
from google.cloud import language
from google.cloud.language import types
from google.cloud.language import enums

client = language.LanguageServiceClient()

def tokenize(title):
    document = types.Document(content=title, type=enums.Document.Type.PLAIN_TEXT)
    tokens = client.analyze_syntax(document).tokens
    tokenized_text = " ".join([token.text.content for token in tokens])
    return tokenized_text

df['tokenized_title'] = df.title.apply(tokenize)

df
# Out:
#         source                                              title  \
# 0   techcrunch            From Social Networks to Market Networks
# 1   techcrunch                     地下貯蔵庫を持つワイン購入サイトが無料のワインボトルを進呈中
# 2   techcrunch  Underground Cellar A Wine-Buying Site That Rew...
# 3   techcrunch          AndroidユーザーはGoogle Playで公開予定のアプリの事前登録が可能に
# 4   techcrunch  Android Users Can Now Pre-Register for Upcomin...
# 5   techcrunch                                 最新500社のスタートアップ企業一覧
# 6   techcrunch  Here s the Latest Batch of 500 Startups Companies
# 7      nytimes       Google Unveils Plan for New Corporate Campus
# 8      nytimes                             Google、新しい企業キャンパス計画を発表
# 9      nytimes  The Risk of a Billion-Dollar Valuation in Sili...
# 10     nytimes                            シリコンバレーにおける10億ドルの評価のリスク
# 11     nytimes  NYC Mayor to require computer science in city ...
# 12     nytimes  4chan Message Board Sold  to Founder of 2Chann...
# 13     nytimes  Big Price Increase for Tuberculosis Drug Is Re...
# 14  techcrunch  The 6 TechCrunch Disrupt SF 2015 Battlefield F...
# 15     nytimes                 Is College Tuition Really Too High
# 16     nytimes                                      大学の授業料は本当に高い?
#
#                      time_ts        id  \
# 0  2015-06-28 00:31:48+00:00   9791977
# 1  2015-10-29 00:54:20+00:00   9791978
# 2  2015-10-29 00:54:20+00:00   9791978
# 3  2015-10-01 00:54:20+00:00   9791979
# 4  2015-10-01 00:54:20+00:00   9791979
# 5  2015-11-03 00:54:20+00:00   9791980
# 6  2015-11-03 00:54:20+00:00   9791980
# 7  2015-08-12 00:02:29+00:00  10045195
# 8  2015-08-12 00:02:29+00:00  10045195
# 9  2015-08-29 00:54:20+00:00  10138569
# 10 2015-08-29 00:54:20+00:00  10138569
# 11 2015-09-15 23:29:44+00:00  10223767
# 12 2015-09-21 22:41:41+00:00  10255585
# 13 2015-09-21 22:43:57+00:00  10255601
# 14 2015-09-23 06:36:19+00:00  10263615
# 15 2015-09-29 04:50:13+00:00  10294707
# 16 2015-09-29 04:50:13+00:00  10294707
#
#                                       tokenized_title
# 0             From Social Networks to Market Networks
# 1       地下 貯蔵 庫 を 持つ ワイン 購入 サイト が 無料 の ワイン ボトル を 進呈 中
# 2   Underground Cellar A Wine - Buying Site That R...
# 3   Android ユーザー は Google Play で 公開 予定 の アプリ の 事前 ...
# 4   Android Users Can Now Pre-Register for Upcomin...
# 5                           最新 500 社 の スタート アップ 企業 一覧
# 6   Here s the Latest Batch of 500 Startups Companies
# 7        Google Unveils Plan for New Corporate Campus
# 8                       Google 、 新しい 企業 キャンパス 計画 を 発表
# 9   The Risk of a Billion - Dollar Valuation in Si...
# 10                   シリコン バレー における 10 億 ドル の 評価 の リスク
# 11  NYC Mayor to require computer science in city ...
# 12  4chan Message Board Sold to Founder of 2Channe...
# 13  Big Price Increase for Tuberculosis Drug Is Re...
# 14  The 6 TechCrunch Disrupt SF 2015 Battlefield F...
# 15                 Is College Tuition Really Too High
# 16                              大学 の 授業 料 は 本当 に 高い ?

# %% [markdown]
# ## Tokenize a second time
#
# This time, tokenization is successful.

# %%
vocab = vectorizer.fit(df.tokenized_title).vocabulary_
vocab_df = pd.DataFrame(vocab.items())
vocab_df
# Out:
#                0    1
# 0             予定   98
# 1        founder   28
# 2    battlefield    8
# 3         dollar   24
# 4          キャンパス   87
# 5       startups   66
# 6             評価  114
# 7          mayor   40
# 8         market   39
# 9            web   80
# 10          from   30
# 11            進呈  117
# 12           バレー   92
# 13          apps    6
# 14            to   70
# 15         board   11
# 16          2015    1
# 17        valley   78
# 18       disrupt   23
# 19    techcrunch   67
# 20           500    4
# 21           too   71
# 22       rewards   57
# 23          risk   58
# 24      upcoming   76
# 25          that   68
# 26          with   82
# 27           big    9
# 28          site   63
# 29   underground   74
# ..           ...  ...
# 89           ワイン   96
# 90          スタート   90
# 91            公開  101
# 92          free   29
# 93       tuition   73
# 94            大学  104
# 95           新しい  107
# 96          here   32
# 97        latest   38
# 98           the   69
# 99          における   84
# 100      billion   10
# 101           on   47
# 102           of   46
# 103    rescinded   56
# 104     register   54
# 105         ユーザー   94
# 106         シリコン   89
# 107         drug   25
# 108           sf   61
# 109      silicon   62
# 110           ドル   91
# 111         wine   81
# 112       social   64
# 113          リスク   95
# 114          サイト   88
# 115          アップ   85
# 116          ボトル   93
# 117          you   83
# 118           本当  109
#
# [119 rows x 2 columns]

# %% [markdown]
# # Appendix - Original query to extract Hacker News headlines from BigQuery

# %% [markdown]
# ```
# SELECT
#   source,
#   REGEXP_REPLACE(title, '[^a-zA-Z0-9 $.-]', ' ') AS title,
#   time_ts,
#   id
# FROM
# (SELECT
#   ARRAY_REVERSE(SPLIT(REGEXP_EXTRACT(url, '.*://(.[^/]+)/'), '.'))[OFFSET(1)] AS source,
#   title,
#   time_ts,
#   id
#  FROM
#   `bigquery-public-data.hacker_news.stories`
#  WHERE
#   REGEXP_CONTAINS(REGEXP_EXTRACT(url, '.*://(.[^/]+)/'), '.com$')
#   AND LENGTH(title) > 10
# )
# WHERE (source = 'techcrunch' OR source = 'nytimes') AND time_ts > '2015-01-01'
# ```
